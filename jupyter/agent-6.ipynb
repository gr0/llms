# %%
pip install "openai>=1.76.0" "pydantic>=2.10,<3" "griffe>=1.5.6,<2" "typing-extensions>=4.12.2,<5" "requests>=2.0,<3" "types-requests>=2.0,<3" "beautifulsoup4" "reportlab" "mcp>=1.6.0,<2; python_version >= '3.10'"

# %%
pip install openai-agents

# %%
pip install rich

# %%
from pydantic import BaseModel

from agents import Agent

PLANNER_PROMPT = (
    "You are a helpful research assistant. Given a query, come up with a set of web searches "
    "to perform to best answer the query. Output between 5 and 20 terms to query for."
)

class WebSearchItem(BaseModel):
    reason: str
    "Your reasoning for why this search is important to the query."

    query: str
    "The search term to use for the web search."


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem]
    """A list of web searches to perform to best answer the query."""


planner_agent = Agent(
    name="PlannerAgent",
    instructions=PLANNER_PROMPT,
    model="gpt-4o",
    output_type=WebSearchPlan,
)

# %%
from agents import Agent, WebSearchTool
from agents.model_settings import ModelSettings

INSTRUCTIONS = (
    "You are a research assistant. Given a search term, you search the web for that term and "
    "produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 "
    "words. Capture the main points. Write succinctly, no need to have complete sentences or good "
    "grammar. This will be consumed by someone synthesizing a report, so its vital you capture the "
    "essence and ignore any fluff. Do not include any additional commentary other than the summary "
    "itself. Do not search in more then 10 pages."
)

search_agent = Agent(
    name="Search agent",
    instructions=INSTRUCTIONS,
    tools=[WebSearchTool()],
    model_settings=ModelSettings(tool_choice="required"),
)

# %%
from pydantic import BaseModel

from agents import Agent

WRITER_PROMPT = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research "
    "assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words."
)


class ReportData(BaseModel):
    short_summary: str
    """A short 2-3 sentence summary of the findings."""

    markdown_report: str
    """The final report"""

    follow_up_questions: list[str]
    """Suggested topics to research further"""

writer_agent = Agent(
    name="WriterAgent",
    instructions=WRITER_PROMPT,
    model="o3-mini",
    output_type=ReportData,
)

# %%
from typing import Any

from rich.console import Console, Group
from rich.live import Live
from rich.spinner import Spinner


class Printer:
    def __init__(self, console: Console):
        self.live = Live(console=console)
        self.items: dict[str, tuple[str, bool]] = {}
        self.hide_done_ids: set[str] = set()
        self.live.start()

    def end(self) -> None:
        self.live.stop()

    def hide_done_checkmark(self, item_id: str) -> None:
        self.hide_done_ids.add(item_id)

    def update_item(
        self, item_id: str, content: str, is_done: bool = False, hide_checkmark: bool = False
    ) -> None:
        self.items[item_id] = (content, is_done)
        if hide_checkmark:
            self.hide_done_ids.add(item_id)
        self.flush()

    def mark_item_done(self, item_id: str) -> None:
        self.items[item_id] = (self.items[item_id][0], True)
        self.flush()

    def flush(self) -> None:
        renderables: list[Any] = []
        for item_id, (content, is_done) in self.items.items():
            if is_done:
                prefix = "✅ " if item_id not in self.hide_done_ids else ""
                renderables.append(prefix + content)
            else:
                renderables.append(Spinner("dots", text=content))
        self.live.update(Group(*renderables))

# %%
from __future__ import annotations

import asyncio
import time

from rich.console import Console

from agents import Runner, custom_span, gen_trace_id, trace

class ResearchManager:
    def __init__(self):
        self.console = Console()
        self.printer = Printer(self.console)

    async def run(self, query: str) -> None:
        trace_id = gen_trace_id()
        with trace("Research trace", trace_id=trace_id):
            self.printer.update_item(
                "trace_id",
                f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}",
                is_done=True,
                hide_checkmark=True,
            )

            self.printer.update_item(
                "starting",
                "Starting research...",
                is_done=True,
                hide_checkmark=True,
            )
            search_plan = await self._plan_searches(query)
            search_results = await self._perform_searches(search_plan)
            report = await self._write_report(query, search_results)

            final_report = f"Report summary\n\n{report.short_summary}"
            self.printer.update_item("final_report", final_report, is_done=True)

            self.printer.end()

        print("\n\n=====REPORT=====\n\n")
        print(f"Report: {report.markdown_report}")
        print("\n\n=====FOLLOW UP QUESTIONS=====\n\n")
        follow_up_questions = "\n".join(report.follow_up_questions)
        print(f"Follow up questions: {follow_up_questions}")

    async def _plan_searches(self, query: str) -> WebSearchPlan:
        self.printer.update_item("planning", "Planning searches...")
        result = await Runner.run(
            planner_agent,
            f"Query: {query}",
        )
        self.printer.update_item(
            "planning",
            f"Will perform {len(result.final_output.searches)} searches",
            is_done=True,
        )
        return result.final_output_as(WebSearchPlan)

    async def _perform_searches(self, search_plan: WebSearchPlan) -> list[str]:
        with custom_span("Search the web"):
            self.printer.update_item("searching", "Searching...")
            num_completed = 0
            tasks = [asyncio.create_task(self._search(item)) for item in search_plan.searches]
            results = []
            for task in asyncio.as_completed(tasks):
                result = await task
                if result is not None:
                    results.append(result)
                num_completed += 1
                self.printer.update_item(
                    "searching", f"Searching... {num_completed}/{len(tasks)} completed"
                )
            self.printer.mark_item_done("searching")
            return results

    async def _search(self, item: WebSearchItem) -> str | None:
        input = f"Search term: {item.query}\nReason for searching: {item.reason}"
        try:
            result = await Runner.run(
                search_agent,
                input,
            )
            return str(result.final_output)
        except Exception:
            return None

    async def _write_report(self, query: str, search_results: list[str]) -> ReportData:
        self.printer.update_item("writing", "Thinking about report...")
        input = f"Original query: {query}\nSummarized search results: {search_results}"
        result = Runner.run_streamed(
            writer_agent,
            input,
        )
        update_messages = [
            "Thinking about report...",
            "Planning report structure...",
            "Writing outline...",
            "Creating sections...",
            "Cleaning up formatting...",
            "Finalizing report...",
            "Finishing report...",
        ]

        last_update = time.time()
        next_message = 0
        async for _ in result.stream_events():
            if time.time() - last_update > 5 and next_message < len(update_messages):
                self.printer.update_item("writing", update_messages[next_message])
                next_message += 1
                last_update = time.time()

        self.printer.mark_item_done("writing")
        return result.final_output_as(ReportData)

# %%
query = input("What would you like to research? ")
await ResearchManager().run(query)
# Out:
# What would you like to research?  Raport o tym jak Stefan Batory spotkał Smoka Wawelskiego
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# =====REPORT=====
#
#
# Report: # Raport o tym, jak Stefan Batory spotkał Smoka Wawelskiego
#
# ## Spis Treści
#
# 1. [Wprowadzenie](#wprowadzenie)
# 2. [Stefan Batory – Człowiek, Król i Inicjator Reform](#stefan-batory)
# 3. [Legenda o Smoku Wawelskim](#smok-wawelski)
# 4. [Punkty Styku Historii i Legendy](#punkty-styku)
# 5. [Analiza Kulturowa i Symboliczna](#analiza-kulturowa)
# 6. [Próby Łączenia Mitologii z Historycznym Kontekstem](#lączenie-konceptu)
# 7. [Wnioski](#wnioski)
# 8. [Podsumowanie](#podsumowanie)
#
# ## Wprowadzenie <a name="wprowadzenie"></a>
#
# Legenda i historia w Polsce często splatają się w fascynujący sposób, tworząc opowieści, które przekraczają granice czasowe i gatunkowe. W niniejszym raporcie podjęto próbę rekonstrukcji możliwego spotkania Stefana Batorego, jednego z najwybitniejszych królów Rzeczypospolitej, oraz Smoka Wawelskiego, symbolu krakowskiej tożsamości kulturowej. Celem dokumentu jest zbadanie potencjalnych punktów styku między postacią historyczną a mityczną, analiza dostępnej literatury i przedstawienie refleksji, dlaczego takie spotkanie mogłoby być interesujące z perspektywy kulturowej i artystycznej.
#
# ## Stefan Batory – Człowiek, Król i Inicjator Reform <a name="stefan-batory"></a>
#
# Stefan Batory (1533–1586) – postać o doniosłym znaczeniu w historii Polski – znany jest przede wszystkim z przeprowadzonych reform wojskowych oraz umacniania pozycji monarchii wobec szlachty. Jego rządy cechowały się militarną precyzją i odważnym prowadzeniem kampanii, co zaowocowało licznymi zwycięstwami, m.in. podczas wojny z Moskwą w kontekście wojny inflanckiej.
#
# ### Kontekst historyczny
#
# Batory, pochodzenia węgierskiego, zdobył tron polski w wyniku małżeństwa z Anną Jagiellonką oraz dzięki poparciu polskiej szlachty i elit politycznych. Jego panowanie było okresem dynamicznych przemian, w których na pierwszy plan wysunęła się modernizacja armii, rozwój szkolnictwa (m.in. fundacja Akademii Wileńskiej) oraz umacnianie władzy centralnej. W dziełach literackich jest przedstawiany jako postać wzniosła, na wzór antycznych bohaterów, co nadaje mu niemal legendarny status.
#
# ### Wizerunek w sztuce i kulturze
#
# Postać Batorego była tematem wielu dzieł sztuki. Znane obrazy, takie jak „Stephen Báthory at Pskov” autorstwa Jana Matejki, przedstawiają go jako postać zdecydowaną, dynamiczną i zwycięską. Jego wizerunek został upowszechniony nie tylko poprzez malarstwo, ale też w literaturze i historii – setki książek, artykułów oraz opracowań naukowych analizowało jego wpływ na kształtowanie polskiej mentalności narodowej.
#
# ## Legenda o Smoku Wawelskim <a name="smok-wawelski"></a>
#
# Smok Wawelski to jedna z najbardziej znanych i rozpoznawalnych postaci w polskim folklorze. Według legendy, smok zamieszkiwał jaskinię pod Wawelem, terroryzując mieszkańców Krakowa i żądając ofiar. Najbardziej znana wersja opowieści opowiada o sprytnym szewczyku, który oszukał bestię, podkładając jej owcę wypchaną siarką. Po zjedzeniu owcy, smok pił wodę z Wisły, aż uległ przegrzaniu i eksplodował, który to sposób stał się symbolem triumfu sprytu nad siłą niebezpieczeństwa.
#
# ### Historyczne i kulturowe źródła legendy
#
# Pierwsze spisane wersje tej opowieści pochodzą z XII–XIII wieku, a Wincenty Kadłubek w swojej "Kronice polskiej" przyczynił się do utrwalenia obrazu potwora jako zagrożenia dla miasta. Z czasem legenda została upiększona, zyskując kolejne warstwy symboliczne – od strażnika grodu po personifikację zbiorowych lęków mieszkańców Krakowa. Współcześnie, Smoka Wawelskiego można zobaczyć nie tylko w literaturze, ale także jako atrakcję turystyczną – rzeźby, spektakle teatralne czy interaktywne instalacje, jak aplikacja „Wawel Dragon AR”, utrwalają tę legendę w świadomości społecznej.
#
# ## Punkty Styku Historii i Legendy <a name="punkty-styku"></a>
#
# Na pierwszy rzut oka postać historyczna, jaką był Stefan Batory, i mityczny smok z Wawelu wydają się pochodzić z zupełnie odmiennych światów. Jednak w analizie kulturowej można dostrzec kilka interesujących punktów styku:
#
# 1. **Symbolika Walki i Zwycięstwa:** Zarówno Batory, jak i smok są związani z pojęciem walki. Batory symbolizuje triumf rozumu, organizacji i siły militarnej nad chaosami epoki, podczas gdy opowieść o smoku przekazuje ideę zwycięstwa sprytu nad pierwotnym zagrożeniem.
#
# 2. **Mitologizacja Postaci Historycznych:** W kulturze polskiej historyczne postaci często nabierają wymiaru mitycznego. Batory, podobnie jak legendarny król Krakus, stał się bohaterem opowieści, w których granica między faktem a bajką zaciera się. Można zatem hipotetycznie rozważać scenariusze fabularne, w których legendy i historia splatają się ze sobą.
#
# 3. **Świętość Miejsca:** Kraków, gdzie toczy się opowieść o Smoku Wawelskim, to miasto naznaczone głęboką symboliką narodową. Obecność Batorego, jako jednego z największych królów Rzeczypospolitej, w takim środowisku kulturowym mogłaby dodatkowo wzbogacić przekaz o wartości patriotyczne i honor historyczny.
#
# ## Analiza Kulturowa i Symboliczna <a name="analiza-kulturowa"></a>
#
# ### Kulturowe znaczenie legend
#
# Legendy, takie jak opowieść o Smoku Wawelskim, pełnią w społeczeństwie funkcję nie tylko rozrywkową, ale również edukacyjną i integracyjną. Poprzez opowieści przekazywane z pokolenia na pokolenie, społeczność buduje wspólne poczucie tożsamości oraz wspomnienia zbiorowe. W ten sposób smok, mimo że jest mityczną istotą, staje się nośnikiem kulturowych wartości.
#
# ### Batoreizm a elementy mityczne
#
# Stefan Batory, choć jest postacią w pełni historyczną, został osnuty wokół aury niemal mitycznej dzięki licznym opowieściom i przekazom, które przetrwały do dzisiejszych czasów. Używanie symboliki antycznej, organizowanie wystawnych procesji oraz wzmianki o heroicznych czynach czy niezwykłych wydarzeniach – wszystko to przyczynia się do tego, że postać Batorego staje się również bohaterem legend, gdzie fakt ulega mityzacji.
#
# ### Spotkanie świata rzeczywistego ze światem baśni
#
# Gdyby spróbować wyobrazić sobie spotkanie Stefana Batorego ze Smoczym wizerunkiem, mogłoby ono mieć wymiar symboliczny. Można przypuszczać, że taki mitologiczny dialog miałby na celu połączenie wartości militarnych i administracyjnych z duchowością, mądrością ludowej tradycji. Spotkanie mogłoby być interpretowane jako symboliczne uhonorowanie triumfu rozumu nad pierwotnym chaosem, a jednocześnie jako przypomnienie o konieczności pielęgnowania dziedzictwa kulturowego.
#
# ## Próby Łączenia Mitologii z Historycznym Kontekstem <a name="lączenie-konceptu"></a>
#
# ### W literaturze i sztuce
#
# W polskiej literaturze i sztuce istnieje wiele przykładów łączenia faktów historycznych z elementami mitycznymi. Niewątpliwie, artyści często korzystają z postaci historycznych, nadając im cechy baśniowe i umieszczając ich w fikcyjnych scenariuszach, które mają na celu podkreślenie wartości moralnych, patriotycznych czy społecznych. Mimo że nie istnieją udokumentowane opowieści o spotkaniu Batorego ze Smokiem Wawelskim, literatura dziecięca oraz adaptacje teatralne, takie jak „Dragon!” wystawiane na Wawelu, pokazują, że połączenie postaci historycznych z legendarnymi jest możliwe i cieszy się popularnością.
#
# ### Nowatorskie podejścia do narracji historyczno-mitologicznej
#
# Coraz częściej twórcy sięgają po nowoczesne technologie, aby ożywić tradycyjne legendy. Przykładem może być aplikacja AR, która pozwala na interaktywny kontakt z postacią Smoka Wawelskiego. W podobnym duchu mogłaby powstać narracja łącząca historię Batorego z mitycznymi elementami, gdzie interaktywność i multimedialność umożliwiłaby odbiorcom głębsze zanurzenie się w legendę. Takie projekty medialne nie tylko odpowiadają na zapotrzebowanie współczesnego widza, ale również stwarzają przestrzeń do nowej interpretacji tradycyjnych opowieści.
#
# ### Współczesne mity i reinterpretacje
#
# Współczesna kultura pokazuje, że granice między faktem a fikcją są płynne. Przykłady adaptacji, jak nowoczesne filmy science fiction inspirowane legendą smoka, a także działalność artystyczna skupiająca się na historycznych postaciach, dowodzą, że reinterpretacja dawnych opowieści nadal ma miejsce. W tym kontekście spotkanie Stefana Batorego i Smoka Wawelskiego mogłoby stanowić fascynującą opowieść, która łączyłaby elementy epopei rycerskiej z magią i tajemnicą współczesnych technologii medialnych.
#
# ## Wnioski <a name="wnioski"></a>
#
# Na podstawie analizy dostępnych źródeł i literatury, jednoznacznie wynika, że:
#
# 1. W dokumentach historycznych nie istnieje żaden wiarygodny dowód na to, że Stefan Batory kiedykolwiek spotkał Smoka Wawelskiego.
# 2. Legenda o Smoku Wawelskim ma swoje korzenie w średniowiecznych opowieściach związanych z mitologią krakowską, natomiast postać Batorego pojawiła się w historii kilka stuleci później, jako symbol militarnego i administracyjnego sukcesu.
# 3. Choć nie ma historycznego powiązania między Batorego a smokiem, granica między legendą a historią w polskiej kulturze bywa płynna. Jest to szczególnie widoczne w sposobie, w jaki współczesne media i sztuka reinterpretują tradycyjne opowieści, wprowadzając innowacyjne rozwiązania narracyjne i multimedialne.
# 4. Proces łączenia faktów historycznych z elementami mitologicznymi odbywa się głównie poprzez artystyczną licencję twórczą, która pozwala na tworzenie narracji pobudzających wyobraźnię odbiorców, co może być cennym narzędziem edukacyjnym i kulturowym.
#
# ## Podsumowanie <a name="podsumowanie"></a>
#
# Podsumowując, raport wykazuje, że choć historyczne realia panowania Stefana Batorego oraz mityczna opowieść o Smoku Wawelskim pochodzą z odrębnych tradycji, ich symbioza w wyobraźni społecznej jest możliwa i nawet pożądana. Brak jest jednak bezpośrednich, historycznych przesłanek łączących Batorego z legendarną bestią, co świadczy o tym, że spotkanie to należy do sfery literackiej i symbolicznej interpretacji. Taka narracja, choć fikcyjna, może mieć wartość pedagogiczną, pokazując, jak mit i historia mogą inspirować współczesne pokolenia i budować tożsamość kulturową.
#
# Dodatkowo, warto podkreślić, że analiza ta zachęca do refleksji nad sposobem, w jaki legendy wpływają na nasze postrzeganie historii. Kreatywne podejście do łączenia postaci historycznych z elementami mitycznymi stanowi interesujący obszar badań interdyscyplinarnych, w którym historia, literatura, sztuka i technologia znajdują wspólny język w narracji kulturowej.
#
# W konkluzji, spotkanie Stefana Batorego ze Smokiem Wawelskim jest raczej produktem współczesnej wyobraźni artystycznej niż faktem historycznym. Niemniej jednak, potencjał takiej narracji pokazuje, jak elastyczne mogą być granice naszej wiedzy o przeszłości, gdy poddawane są reinterpretacji w świetle nowych wyzwań kulturowych i medialnych.
#
# ---
#
# Autor raportu sugeruje, że dalsze badania powinny skupić się na eksploracji sposobów, w jakie mitologia może wzmacniać przekaz pedagogiczny historii oraz na projektach artystycznych łączących nowoczesne technologie z tradycyjnymi legendami, co otwiera nowy rozdział w interdyscyplinarnych studiach kulturowych.
#
#
#
# =====FOLLOW UP QUESTIONS=====
#
#
# Follow up questions: Czy warto rozwijać projekty artystyczne łączące legendy z faktami historycznymi?
# Jakie są potencjalne korzyści edukacyjne z reinterpretacji legend na potrzeby współczesnych mediów?
# Czy istnieją inne przykłady w historii Polski, gdzie postacie historyczne łączone są z elementami mitologicznymi?
# Jak współczesna technologia może wpłynąć na odbiór tradycyjnych opowieści i legend?
